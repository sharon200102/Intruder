# %%
from intruder.runner import WorkshopRunner
from intruder.video.video import FRAME
from intruder.video.video_base_objects import CocoBbox

first_task_runner = WorkshopRunner(task_num=1)
# Out:
# An example video for task 1 was created in /home/sharonkomissarov/internal/code/Intruder/src/intruder/data/task_1/data/exmple.mp4

# %% [markdown]
# ## FIRST TASK: Find them when they are not moving

# %%
class FirstTaskSolution:
    def __init__(self):
        pass

    def solution(frame:FRAME) -> list[CocoBbox]:
        """
        Your code goes here (:

        You should write a code that takes the frame and finds the objects in it.
        return the bounding boxes around each object as we learned in class

        Args:
            frame (FRAME): a numpy frame of shape [Height,Width] that includes the objects you need to find

        Returns:
            list[CocoBbox]: A list of tuples (x top left corner, y top left corner, width, height)
        """
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 class FirstTaskSolution:
#       2     def __init__(self):
#       3         pass
#
# Cell In[4], line 5, in FirstTaskSolution()
#       2 def __init__(self):
#       3     pass
# ----> 5 def solution(frame:FRAME) -> list[CocoBbox]:
#       6     """
#       7     Your code goes here (:
#       8
#    (...)
#      13         list[CocoBbox]: A list of tuples (x top left corner, y top left corner, width, height)
#      14     """
#
# NameError: name 'FRAME' is not defined

# %%
first_task_solution = FirstTaskSolution()
first_task_runner.run_solution(first_task_solution.solution)

# %% [markdown]
# ## SECOND TASK: Oh no :( they can move now
# ### Can you still find them?

# %%
second_task_runner = WorkshopRunner(task_num=2)

# %%
class SecondTaskSolution:
    def __init__(self):
        pass

    def solution(frame:FRAME) -> list[CocoBbox]:
        """
        Your code goes here (:

        You should write a code that takes the frame and finds the objects in it.
        return the bounding boxes around each object as we learned in class

        Args:
            frame (FRAME): a numpy frame of shape [Height,Width] that includes the objects you need to find

        Returns:
            list[CocoBbox]: A list of tuples (x top left corner, y top left corner, width, height)
        """

# %%
second_task_solution = SecondTaskSolution()
second_task_runner.run_solution(second_task_solution.solution)

# %% [markdown]
# ## THIRD TASK: There is so much noise I can't see them
# ### Can you spot the enemy when the bacground is not clear?

# %%
third_task_runner = WorkshopRunner(task_num=3)

# %%
class ThirdTaskSolution:
    def __init__(self):
        pass

    def solution(frame:FRAME) -> list[CocoBbox]:
        """
        Your code goes here (:

        You should write a code that takes the frame and finds the objects in it.
        return the bounding boxes around each object as we learned in class

        Args:
            frame (FRAME): a numpy frame of shape [Height,Width] that includes the objects you need to find

        Returns:
            list[CocoBbox]: A list of tuples (x top left corner, y top left corner, width, height)
        """

# %%
third_task_solution = ThirdTaskSolution()
third_task_runner.run_solution(third_task_solution.solution)
